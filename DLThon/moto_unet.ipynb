# %% [markdown]
# # Motocycle Night Ride
# ---
# ## 데이터 셋 준비
#
# ### Kaggle Motorcycle Night Ride
#
# #### Label 이미지로 부터 클래스 색상 확인

# %%
#필요한 라이브러리를 로드합니다. 
import os
import math
import random
import numpy as np
import tensorflow as tf

from PIL import Image
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from glob import glob

# from tensorflow.keras.models import *
# from tensorflow.keras.layers import *
# from tensorflow.keras.optimizers import *
from albumentations import  HorizontalFlip, RandomSizedCrop, Compose, OneOf, Resize

# %%
# label 이미지 파일 경로 list
dir_path = './data/images' # Kaggle 에서 다운로드 받은 파일 내 images 폴더 경로   

label_images = glob(os.path.join(dir_path, "night ride (*).png___fuse.png"))

# sample 이미지 확인
output_path = label_images[0]
_output = imread(output_path)[:,:,:3] # 알파 채널 제거
print('image shape:', _output.shape)

# 클래스 컬러와 클래스 매핑을 추출하는 함수
def extract_class_color_mapping(color_mask):
    unique_colors = np.unique(color_mask.reshape(-1, 3), axis=0)
    class_mapping = {}
    for idx, color in enumerate(unique_colors):
        class_mapping[tuple(color)] = idx
    return class_mapping

# 클래스 컬러와 매핑 추출
rgb_class_map = extract_class_color_mapping(_output)
class_rgb_map = {v:k for k,v in rgb_class_map.items()}    
plt.imshow(_output)
plt.axis('off')
plt.show()

plt.figure(figsize=(15, 10))
for i, rgb in class_rgb_map.items():
    plt.subplot(2, 3, i + 1)
    r,g,b = rgb
    cbox = np.ones((1, 1, 3), dtype=np.uint8) * 255
    cbox[0:1, 0:1] = [r,g,b]
    plt.imshow(cbox)
    plt.title(f'Class {i} : ({r},{g},{b})')
    plt.axis('off')  # 축 숨기기
plt.show()
# Out:
# image shape: (1080, 1920, 3)

# %% [markdown]
# ### 클래스 맵 정의

# %%
#     '0' (57, 234, 92): 'Movable', 
#     '1' (65, 117, 6): 'Rider', 
#     '2' (74, 144, 226): 'My bike', 
#     '3' (155, 155, 155): 'Road', 
#     '4' (245, 166, 35): 'Undrivable', 
#     '5' (248, 231, 28): 'Lanemark'

def rgb_to_label(r,g,b):    
    try :
        return rgb_class_map[(r,g,b)]
    except:
        # 알수 없는 색상의 경우 Undrivable : 4 반환
        return 4
def label_to_rgb(label):
    try :
        return class_rgb_map[label]
    except:
        return (0, 0, 0)

# rgb(3채널) 이미지를 class(1채널)텐서로 변환
def get_target(mask):
    height = mask.shape[0]
    width = mask.shape[1]
    target = np.zeros((height, width, 1), dtype=np.uint8)
    for h in range(height):
        for w in range(width):
            r,g,b = mask[h,w]
            target[h, w, 0] = int(rgb_to_label(r,g,b))
    return target

# class(1채널)텐서를 rgb(3채널)변환 이미지 및 클래스 별 빈도수 반환
def get_mask(target, is_pred=False):
    height = target.shape[0]
    width = target.shape[1]
    mask = np.zeros((height, width, 3), dtype=np.uint8) # 마스크 이미지
    
    num_classes = len(class_rgb_map)
    ccnts = np.zeros(num_classes, dtype=np.uint8)  # 클래스 별 카운트
    pred_target = np.zeros((height, width, 1), dtype=np.uint8)
    for h in range(height):
        for w in range(width):
            if is_pred:
                # target : 모델 예측 결과 텐서 (height, width, 6)                
                label = int(np.argmax(target[h,w]))
                pred_target[h,w,0]=label
            else:
                # target : Label이미지 텐서 (height, width, 1)
                label = int(target[h,w,0])
            ccnts[label] += 1
            r,g,b = label_to_rgb(label)
            mask[h, w, 0] = r
            mask[h, w, 1] = g
            mask[h, w, 2] = b
            
    return mask, ccnts, pred_target

# %% [markdown]
# #### 훈련, 검증, 테스트 데이터 Generator 구현

# %%
###################################################################################
# Augumetation
###################################################################################
def build_augmentation(is_train=True):
    if is_train:    # 훈련용 데이터일 경우
        return Compose([
            HorizontalFlip(p=0.5),    # 50%의 확률로 좌우대칭
            RandomSizedCrop(         # 50%의 확률로 RandomSizedCrop
                min_max_height=(300, 370),
                w2h_ratio=370/1242,
                height=224,
                width=224,
                p=0.5
            ),
            Resize(              # 입력이미지를 224X224로 resize
                width=224,
                height=224
            )
        ])
    return Compose([      # 테스트용 데이터일 경우에는 224X224로 resize만 수행합니다. 
        Resize(
            width=224,
            height=224
        )
    ])

# %%
###################################################################################
# CustomGenerator
###################################################################################
class CustomGenerator(tf.keras.utils.Sequence):    
    '''
    CustomGenerator tf.keras.utils.Sequence를 상속받습니다.
    '''    
    def __init__(self, 
                 data_loader,
                 batch_size=16,
                 img_size=(224, 224, 3),
                 output_size=(224, 224, 1),
                 is_train=True,
                 augmentation=None):        
        '''
        data_loader: dataset의 파일 경로를 받아오는 함수
        batch_size: batch_size입니다.
        img_size: preprocess에 사용할 입력이미지의 크기입니다.
        output_size: ground_truth를 만들어주기 위한 크기입니다.
        is_train: 이 Generator가 학습용인지 테스트용인지 구분합니다.
        augmentation: 적용하길 원하는 augmentation 함수를 인자로 받습니다.
        '''
        self.batch_size = batch_size
        self.is_train = is_train
        self.dir_path = dir_path
        self.augmentation = augmentation
        self.img_size = img_size
        self.output_size = output_size

        # data_loader()을 통해서 라벨과 이미지를 확인
        self.data = data_loader(is_train)
        
    def __len__(self):
        # Generator의 전체 길이를 반환 함수 
        # 전체 dataset을 batch_size로 나누고 소숫점 첫째자리에서 "올림"한 값 반환
        return math.ceil(len(self.data) / self.batch_size)

    def __getitem__(self, index):
        # index값에 따라 데이터를 반환하는 함수
        # 입력과 출력을 만듭니다.
        # 입력은 resize및 augmentation이 적용된 input image이고 
        # 출력은 semantic label입니다.
        batch_data = self.data[
                               index*self.batch_size:
                               (index + 1)*self.batch_size
                               ]
        
        inputs = np.zeros([self.batch_size, *self.img_size])
        outputs = np.zeros([self.batch_size, *self.output_size])

        for i, data in enumerate(batch_data):
            input_img_path, output_path = data
            _input = imread(input_img_path)[:,:,:3] # 알파 채널 제거
            _output = imread(output_path)[:,:,:3]
            #-----------------------------------------------
            # augmentation >>> build_augmentation 함수 변경시 확인 필요
            data = {
                "image": _input,
                "mask": _output,
            }
            augmented = self.augmentation(**data)            
            _input = augmented["image"]
            _output = augmented["mask"]                                            
            #-----------------------------------------------            
            # inputs normalization
            # outputs 이미지 변환 rgb(,,3) >>> label(,,1)
            inputs[i] = _input / 255
            outputs[i] = get_target(_output)
            #-----------------------------------------------
        return inputs, outputs

    def on_epoch_end(self):
        # 한 epoch가 끝나면 실행되는 함수입니다. 학습중인 경우에 순서를 random shuffle하도록 적용한 것을 볼 수 있습니다.
        self.indexes = np.arange(len(self.data))
        if self.is_train == True :
            np.random.shuffle(self.indexes)
        return self.indexes

###################################################################################
def load_motorcycle(is_train = False, is_test=False, shuffle_seed=1234):
    # Motorcycle Night Ride dataset에서 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수
    
    dir_path = './data/images' # 다운로드 받은 데이터 셋의 images 폴더 경로
        
    input_images = glob(os.path.join(dir_path, "night ride (*).png"))
    label_images = glob(os.path.join(dir_path, "night ride (*).png___fuse.png"))
    input_images.sort()
    label_images.sort()
    assert len(input_images) == len(label_images)
    data = [ _ for _ in zip(input_images, label_images)]
    
    random.seed(shuffle_seed)
    random.shuffle(data)
    
    train_ratio = 0.75
    val_ratio = 0.15
    test_ratio = 0.1
    
    total_samples = len(data)
    train_split = int(total_samples * train_ratio)
    val_split = int(total_samples * (train_ratio + val_ratio))

    if is_test:
        return data[val_split:]
    
    if is_train:
        return data[:train_split]
    else:
        return data[train_split:val_split]
    
train_generator = CustomGenerator(
    load_motorcycle, 
    augmentation=build_augmentation(),
)
val_generator = CustomGenerator(
    load_motorcycle, 
    augmentation=build_augmentation(is_train=False),
    is_train=False
)

# %% [markdown]
# ---
# ## U-Net 모델 구현

# %%
def show_data(show_num=3):    
    inputs, outputs = train_generator.__getitem__(0)
    plt.figure(figsize=(15, 15))    
    for i in range(show_num):
        plt.subplot(show_num, 3, 3*i+1)
        plt.axis('off')
        plt.imshow(inputs[i] )
        plt.subplot(show_num, 3, 3*i+2)
        plt.axis('off')
        plt.imshow(outputs[i])
        plt.subplot(show_num, 3, 3*i+3)
        plt.axis('off')
        plt.imshow(get_mask(outputs[i])[0])
    plt.show()

show_data()

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Conv2DTranspose, Concatenate
#########################################################################################
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding='same', kernel_initializer = 'he_normal')(inputs)
    x = BatchNormalization()(x)
    return Activation('relu')(x)

def down_sampling(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    x = conv_block(x, num_filters)
    return x, MaxPooling2D((2, 2))(x)

def up_sampling(inputs, skips, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding='same', kernel_initializer = 'he_normal')(inputs)
    x = Concatenate()(skips + [x])
    x = conv_block(x, num_filters)
    x = conv_block(x, num_filters)
    return x
#########################################################################################
# build_model
#########################################################################################
def build_unet(input_shape=(224, 224, 3), num_classes=1, is_plus=False, deep_supervision=False):    
    
    model_name='U-Net'
#     fsize=[64,128,256,512,1024]    
    fsize=[32,64,128,256,512]
    act = 'sigmoid' if num_classes > 1 else 'softmax'
    
    inputs = Input(shape=input_shape)
    
    x00, x = down_sampling(inputs, fsize[0])
    x10, x = down_sampling(x, fsize[1])
    x20, x = down_sampling(x, fsize[2])
    x30, x = down_sampling(x, fsize[3])
    x40, x = down_sampling(x, fsize[4])
        
    if is_plus:
        # U-Net++ 모델 Up Sampling
        x01 = up_sampling(x10, [x00], fsize[0])
        x11 = up_sampling(x20, [x10], fsize[1])
        x21 = up_sampling(x30, [x20], fsize[2])
        x31 = up_sampling(x40, [x30], fsize[3])

        x02 = up_sampling(x11, [x00, x01], fsize[0])
        x12 = up_sampling(x21, [x10, x11], fsize[1])
        x22 = up_sampling(x31, [x20, x21], fsize[2])

        x03 = up_sampling(x12, [x00, x01, x02], fsize[0])
        x13 = up_sampling(x22, [x10, x11, x12], fsize[1])

        x04 = up_sampling(x13, [x00, x01, x02, x03], fsize[0])
        
        x1 = Conv2D(num_classes, 1, padding='same', activation=act)(x01)
        x2 = Conv2D(num_classes, 1, padding='same', activation=act)(x02)
        x3 = Conv2D(num_classes, 1, padding='same', activation=act)(x03)
        x4 = Conv2D(num_classes, 1, padding='same', activation=act)(x04)
        
        model_name='U-Net_PP'
        x = [x4]
        
        if deep_supervision:        
            model_name='U-Net_PP_DeepSupervision'
            x = [x1, x2, x3, x4] 
            
    else:
        # 기본 U-Net 모델
        x31 = up_sampling(x40, [x30], fsize[3])
        x22 = up_sampling(x31, [x20], fsize[2])
        x13 = up_sampling(x22, [x10], fsize[1])
        x04 = up_sampling(x13, [x00], fsize[0])
        
        x = Conv2D(num_classes, 1, padding='same', activation=act)(x04)
        
    model = tf.keras.models.Model(inputs=inputs, outputs=x, name=model_name)        
    return model    

#########################################################################################
import pickle
def save_model_history(model, history):
    m_path = f'./model_{model.name}.h5'
    model.save(m_path)  #학습한 모델을 저장
    h_path = f'./history_{model.name}.pkl'
    with open(h_path, 'wb') as file:
        pickle.dump(history.history, file)
    return model, history

# %% [markdown]
# ## 모델 학습
# ---
# ### U-Net 모델 학습

# %%
# U-Net모델
m_unet = build_unet(num_classes=len(class_rgb_map))
m_unet.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=[])
m_unet.summary()
h_unet = m_unet.fit(
    train_generator,
    validation_data=val_generator,
    steps_per_epoch=len(train_generator),
    epochs=100
)
save_model_history(m_unet, h_unet)
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 224, 224, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 224, 224, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 9248        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 112, 32) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 112, 112, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 112, 112, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 112, 112, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 64) 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 112, 112, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 112, 112, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 128)  147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 14, 14, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 14, 14, 512)  2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 512)  2359808     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 28, 28, 256)  524544      activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 28, 28, 512)  0           activation_7[0][0]
#                                                                  conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 28, 28, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 28, 28, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 28, 28, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 56, 56, 128)  131200      activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 256)  0           activation_5[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 56, 56, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 56, 56, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 56, 56, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 112, 112, 64) 32832       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 112, 112, 128 0           activation_3[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 112, 112, 64) 73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 112, 112, 64) 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 112, 112, 64) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 112, 112, 64) 36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 112, 112, 64) 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 112, 112, 64) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 224, 224, 32) 8224        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 224, 224, 64) 0           activation_1[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 224, 224, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 224, 224, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 224, 224, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 224, 224, 32) 9248        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 224, 224, 32) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 224, 224, 32) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 224, 224, 6)  198         activation_17[0][0]
# ==================================================================================================
# Total params: 7,772,038
# Trainable params: 7,766,150
# Non-trainable params: 5,888
# __________________________________________________________________________________________________
# Epoch 1/100
# 5/5 [==============================] - 29s 4s/step - loss: 1.8675 - val_loss: 1.7647
# Epoch 2/100
# 5/5 [==============================] - 21s 4s/step - loss: 1.7540 - val_loss: 1.7811
# Epoch 3/100
# 5/5 [==============================] - 21s 5s/step - loss: 1.6893 - val_loss: 1.7720
# Epoch 4/100
# 5/5 [==============================] - 21s 5s/step - loss: 1.6243 - val_loss: 1.7571
# Epoch 5/100
# 5/5 [==============================] - 21s 4s/step - loss: 1.5656 - val_loss: 1.7405
# Epoch 6/100
# 5/5 [==============================] - 21s 4s/step - loss: 1.5108 - val_loss: 1.7230
# Epoch 7/100
# 5/5 [==============================] - 20s 4s/step - loss: 1.4565 - val_loss: 1.7193
# Epoch 8/100
# 5/5 [==============================] - 20s 4s/step - loss: 1.3987 - val_loss: 1.7305
# Epoch 9/100
# 5/5 [==============================] - 20s 4s/step - loss: 1.3468 - val_loss: 1.7407
# Epoch 10/100
# 5/5 [==============================] - 21s 4s/step - loss: 1.2853 - val_loss: 1.7301
# Epoch 11/100
# 5/5 [==============================] - 21s 4s/step - loss: 1.2276 - val_loss: 1.7285
# Epoch 12/100
# 5/5 [==============================] - 20s 4s/step - loss: 1.1889 - val_loss: 1.6996
# Epoch 13/100
# 5/5 [==============================] - 20s 4s/step - loss: 1.1437 - val_loss: 1.6733
# Epoch 14/100
# 5/5 [==============================] - 21s 5s/step - loss: 1.0971 - val_loss: 1.5974
# Epoch 15/100
# 5/5 [==============================] - 21s 4s/step - loss: 1.0510 - val_loss: 1.6747
# Epoch 16/100
# 5/5 [==============================] - 21s 4s/step - loss: 1.0091 - val_loss: 1.6431
# Epoch 17/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.9668 - val_loss: 1.6513
# Epoch 18/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.9276 - val_loss: 1.6156
# Epoch 19/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.8899 - val_loss: 1.5616
# Epoch 20/100
# 5/5 [==============================] - 21s 5s/step - loss: 0.8543 - val_loss: 1.5474
# Epoch 21/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.8211 - val_loss: 1.5648
# Epoch 22/100
# 5/5 [==============================] - 21s 5s/step - loss: 0.7882 - val_loss: 1.6523
# Epoch 23/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.7595 - val_loss: 1.5109
# Epoch 24/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.7359 - val_loss: 1.5641
# Epoch 25/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.7067 - val_loss: 1.4932
# Epoch 26/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.6799 - val_loss: 1.5123
# Epoch 27/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.6528 - val_loss: 1.5016
# Epoch 28/100
# 5/5 [==============================] - 21s 5s/step - loss: 0.6291 - val_loss: 1.4704
# Epoch 29/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.6072 - val_loss: 1.5745
# Epoch 30/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.5828 - val_loss: 1.5578
# Epoch 31/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.5647 - val_loss: 1.5601
# Epoch 32/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.5446 - val_loss: 1.6474
# Epoch 33/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.5289 - val_loss: 1.4929
# Epoch 34/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.5107 - val_loss: 1.5858
# Epoch 35/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.4903 - val_loss: 1.6366
# Epoch 36/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.4755 - val_loss: 1.5631
# Epoch 37/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.4602 - val_loss: 1.7233
# Epoch 38/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.4474 - val_loss: 1.6473
# Epoch 39/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.4357 - val_loss: 1.6517
# Epoch 40/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.4240 - val_loss: 1.6741
# Epoch 41/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.4130 - val_loss: 1.7273
# Epoch 42/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.4007 - val_loss: 1.5795
# Epoch 43/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.3897 - val_loss: 1.5710
# Epoch 44/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.3833 - val_loss: 1.5417
# Epoch 45/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.3771 - val_loss: 1.6064
# Epoch 46/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.3759 - val_loss: 1.5880
# Epoch 47/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.3691 - val_loss: 1.5419
# Epoch 48/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.3636 - val_loss: 1.6480
# Epoch 49/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.3527 - val_loss: 1.5757
# Epoch 50/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.3456 - val_loss: 1.5465
# Epoch 51/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.3423 - val_loss: 1.5230
# Epoch 52/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.3354 - val_loss: 1.6544
# Epoch 53/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.3267 - val_loss: 1.4494
# Epoch 54/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.3231 - val_loss: 1.4254
# Epoch 55/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.3168 - val_loss: 1.4002
# Epoch 56/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.3134 - val_loss: 1.3840
# Epoch 57/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.3102 - val_loss: 1.3813
# Epoch 58/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.3064 - val_loss: 1.2972
# Epoch 59/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.3008 - val_loss: 1.3519
# Epoch 60/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2975 - val_loss: 1.3524
# Epoch 61/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.2911 - val_loss: 1.2269
# Epoch 62/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2866 - val_loss: 1.2619
# Epoch 63/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2835 - val_loss: 1.2584
# Epoch 64/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.2793 - val_loss: 1.3276
# Epoch 65/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2767 - val_loss: 1.2390
# Epoch 66/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2722 - val_loss: 1.2165
# Epoch 67/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2687 - val_loss: 1.1783
# Epoch 68/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.2659 - val_loss: 1.2348
# Epoch 69/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2629 - val_loss: 1.1881
# Epoch 70/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2592 - val_loss: 1.2125
# Epoch 71/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.2574 - val_loss: 1.1214
# Epoch 72/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2550 - val_loss: 1.1399
# Epoch 73/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.2527 - val_loss: 1.1020
# Epoch 74/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.2496 - val_loss: 1.1253
# Epoch 75/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2470 - val_loss: 1.1182
# Epoch 76/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2438 - val_loss: 1.0890
# Epoch 77/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2410 - val_loss: 1.0587
# Epoch 78/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2400 - val_loss: 1.0312
# Epoch 79/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2380 - val_loss: 1.0391
# Epoch 80/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.2360 - val_loss: 1.0220
# Epoch 81/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2343 - val_loss: 0.9900
# Epoch 82/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2312 - val_loss: 0.9984
# Epoch 83/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.2332 - val_loss: 0.9248
# Epoch 84/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2296 - val_loss: 0.9448
# Epoch 85/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.2271 - val_loss: 0.8933
# Epoch 86/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2243 - val_loss: 0.9306
# Epoch 87/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.2228 - val_loss: 0.8741
# Epoch 88/100
# 5/5 [==============================] - 21s 4s/step - loss: 0.2225 - val_loss: 0.8531
# Epoch 89/100
# 5/5 [==============================] - 21s 5s/step - loss: 0.2196 - val_loss: 0.8667
# Epoch 90/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.2215 - val_loss: 0.8521
# Epoch 91/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2205 - val_loss: 0.7665
# Epoch 92/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2161 - val_loss: 0.8326
# Epoch 93/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2147 - val_loss: 0.8482
# Epoch 94/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2101 - val_loss: 0.8352
# Epoch 95/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2091 - val_loss: 0.8164
# Epoch 96/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.2088 - val_loss: 0.8086
# Epoch 97/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2071 - val_loss: 0.7678
# Epoch 98/100
# 5/5 [==============================] - 20s 5s/step - loss: 0.2050 - val_loss: 0.7799
# Epoch 99/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2031 - val_loss: 0.7897
# Epoch 100/100
# 5/5 [==============================] - 20s 4s/step - loss: 0.2010 - val_loss: 0.7251
# (<keras.engine.functional.Functional at 0x7fa3545aed30>,
#  <keras.callbacks.History at 0x7fa354591400>)

# %% [markdown]
# ### U-Net++ 모델 학습

# %%
m_unet_pp = build_unet(num_classes=len(class_rgb_map), is_plus=True)
m_unet_pp.summary()
# Out:
# Model: "U-Net_PP"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 224, 224, 32) 896         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 224, 224, 32) 128         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 224, 224, 32) 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 224, 224, 32) 9248        activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 224, 224, 32) 128         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 224, 224, 32) 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 112, 112, 32) 0           activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 112, 112, 64) 18496       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 112, 112, 64) 256         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 112, 112, 64) 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 112, 112, 64) 36928       activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 112, 112, 64) 256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 112, 112, 64) 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 56, 56, 64)   0           activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 56, 56, 128)  73856       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 56, 56, 128)  512         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 56, 56, 128)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 56, 56, 128)  147584      activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 56, 56, 128)  512         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 56, 56, 128)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 28, 28, 128)  0           activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 28, 28, 256)  295168      max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 28, 28, 256)  1024        conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 28, 28, 256)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 28, 28, 256)  590080      activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 28, 28, 256)  1024        conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 28, 28, 256)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 14, 14, 256)  0           activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 14, 14, 512)  1180160     max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 14, 14, 512)  2048        conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 14, 14, 512)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 14, 14, 512)  2359808     activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 14, 14, 512)  2048        conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 14, 14, 512)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 28, 28, 256)  524544      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 56, 56, 128)  131200      activation_61[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 28, 28, 512)  0           activation_61[0][0]
#                                                                  conv2d_transpose_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 112, 112, 64) 32832       activation_59[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 56, 56, 256)  0           activation_59[0][0]
#                                                                  conv2d_transpose_14[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 28, 28, 256)  1179904     concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 224, 224, 32) 8224        activation_57[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 112, 112, 128 0           activation_57[0][0]
#                                                                  conv2d_transpose_13[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 56, 56, 128)  295040      concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 28, 28, 256)  1024        conv2d_73[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 224, 224, 64) 0           activation_55[0][0]
#                                                                  conv2d_transpose_12[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 112, 112, 64) 73792       concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 56, 56, 128)  512         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 28, 28, 256)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 224, 224, 32) 18464       concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 112, 112, 64) 256         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 56, 56, 128)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 28, 28, 256)  590080      activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 224, 224, 32) 128         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 112, 112, 64) 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 56, 56, 128)  147584      activation_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 28, 28, 256)  1024        conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 224, 224, 32) 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 112, 112, 64) 36928       activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 56, 56, 128)  512         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 28, 28, 256)  0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 224, 224, 32) 9248        activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 112, 112, 64) 256         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 56, 56, 128)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 56, 56, 128)  131200      activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 224, 224, 32) 128         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 112, 112, 64) 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 112, 112, 64) 32832       activation_69[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 56, 56, 384)  0           activation_59[0][0]
#                                                                  activation_69[0][0]
#                                                                  conv2d_transpose_18[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 224, 224, 32) 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 224, 224, 32) 8224        activation_67[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 112, 112, 192 0           activation_57[0][0]
#                                                                  activation_67[0][0]
#                                                                  conv2d_transpose_17[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 224, 224, 96) 0           activation_55[0][0]
#                                                                  activation_65[0][0]
#                                                                  conv2d_transpose_16[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 56, 56, 128)  512         conv2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 224, 224, 32) 27680       concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 112, 112, 64) 256         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 56, 56, 128)  0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 224, 224, 32) 128         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 112, 112, 64) 0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 56, 56, 128)  147584      activation_76[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 224, 224, 32) 0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 112, 112, 64) 36928       activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 56, 56, 128)  512         conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 224, 224, 32) 9248        activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 112, 112, 64) 256         conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 56, 56, 128)  0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 224, 224, 32) 128         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 112, 112, 64) 0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 112, 112, 64) 32832       activation_77[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 224, 224, 32) 0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 224, 224, 32) 8224        activation_75[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 112, 112, 256 0           activation_57[0][0]
#                                                                  activation_67[0][0]
#                                                                  activation_75[0][0]
#                                                                  conv2d_transpose_20[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 224, 224, 128 0           activation_55[0][0]
#                                                                  activation_65[0][0]
#                                                                  activation_73[0][0]
#                                                                  conv2d_transpose_19[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 112, 112, 64) 147520      concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 224, 224, 32) 36896       concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 112, 112, 64) 256         conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 224, 224, 32) 128         conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 112, 112, 64) 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 224, 224, 32) 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 112, 112, 64) 36928       activation_80[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 224, 224, 32) 9248        activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 112, 112, 64) 256         conv2d_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 224, 224, 32) 128         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 112, 112, 64) 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 224, 224, 32) 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 224, 224, 32) 8224        activation_81[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 224, 224, 160 0           activation_55[0][0]
#                                                                  activation_65[0][0]
#                                                                  activation_73[0][0]
#                                                                  activation_79[0][0]
#                                                                  conv2d_transpose_21[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 224, 224, 32) 46112       concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 224, 224, 32) 128         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 224, 224, 32) 0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 224, 224, 32) 9248        activation_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 224, 224, 32) 128         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 224, 224, 32) 0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 224, 224, 6)  198         activation_83[0][0]
# ==================================================================================================
# Total params: 9,056,934
# Trainable params: 9,049,638
# Non-trainable params: 7,296
# __________________________________________________________________________________________________

# %% [markdown]
# ## 모델 평가
# ---
# ### 학습 loss 시각화 비교

# %%
plt.figure(figsize=(12, 4))

# train, validation loss graph
plt.subplot(1, 3, 1)
plt.plot(h_unet.history['loss'])
plt.plot(h_unet.history['val_loss'])
plt.title(f'{m_unet.name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')

# plt.subplot(1, 3, 2)
# plt.plot(h_m2.history['loss'])
# plt.plot(h_m2.history['val_loss'])
# plt.title(f'{m2.name}')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['train', 'val'], loc='upper right')

# plt.subplot(1, 3, 3)
# plt.plot(h_m3.history['loss'])
# plt.plot(h_m3.history['val_loss'])
# plt.title(f'{m3.name}')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['train', 'val'], loc='upper right')

plt.show()

# %% [markdown]
# ### 모델 별 테스트 데이터 예측 비교
# - 예측 이미지 시각화 비교
# - mIoU 지표 성능 비교

# %%
def test_model(model, show_num = 1):
    def test_loader(is_train):
        return load_motorcycle(is_test=True)
    test_generator = CustomGenerator(
        test_loader, 
        augmentation=build_augmentation(is_train=False),
    )
    inputs, outputs = test_generator.__getitem__(0)
    pre_tensors = model(inputs)    
    
    plt.figure(figsize=(20, 5 * show_num))
    for i in range(show_num):
        if i == 10:            
            break
        pre_tensor = pre_tensors[i]
        
        # mIoU 계산
        actual = outputs[i]
        mask, actual_cnt, _ = get_mask(actual)
        pred_mask, pred_cnt, pred = get_mask(pre_tensor, is_pred=True)
             
        height, width, num_classes = pre_tensor.shape
#         category = (actual.flatten() * num_classes) + pred.flatten()        
        count = 0
        cm2d = np.zeros((num_classes, num_classes), dtype=np.int32) # Confusion matrix        
        intersection = np.zeros((num_classes), dtype=np.int32)
        for h in range(height):
            for w in range(width):                
                a = int(actual[h,w,0])
                p = int(pred[h,w,0])
                cm2d[a,p] += 1
                if a==p:                    
                    intersection[a] += 1        
        union = np.sum(cm2d, axis=1) + np.sum(cm2d, axis=0) - intersection
        ious = np.around(intersection / union, 3) # 클래스 별 IoU
        miou = round(np.mean(ious),3)
        pixel_accuracy = round(np.sum(intersection) / (width * height), 3)
        
        grid = np.array([[],[],[],[],[],[],[],[]])
        grid = np.column_stack((grid, np.array([0,1,2,3,4,5,'mIoU','pixel accuracy'])))
        grid = np.column_stack((grid, np.concatenate((ious, [miou, pixel_accuracy]))))
        
        



        
        plt.subplot(show_num, 4, 4*i+1)
        plt.imshow(inputs[i])
        plt.title('Image')
        plt.axis('off')
        
        plt.subplot(show_num, 4, 4*i+2)
        plt.imshow(mask)
        plt.title('Label Mask')
        plt.axis('off')
        
        plt.subplot(show_num, 4, 4*i+3)
        plt.imshow(pred_mask)
        plt.title('Prediction')
        plt.axis('off')
        
        plt.subplot(show_num, 4, 4*i+4)
        ptbl = plt.table(cellText=grid, colLabels=['Class', 'IoU'], loc='center')
        ptbl.auto_set_font_size(False)
        ptbl.set_fontsize(12)
#         ptbl.auto_set_column_widths([0,1])
        ptbl.scale(1, 2.5)
        plt.axis('off')
    plt.show()

test_model(m_unet, 1)
